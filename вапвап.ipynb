# %%
* {
  margin: 0;
  padding: 0;
  box-sizing: border-box;
}

body, html {
  height: 100%;
  font-family: 'Georgia', serif;
  background-color: white;
}

.container {
  display: flex;
  height: 100vh;
}

.left-panel, .right-panel {
  width: 50%;
  padding: 60px;
}

.left-panel {
  background-color: #ffffff;
  color: #1c1c1c;
  display: flex;
  flex-direction: column;
  justify-content: space-between;
}

.logo {
  font-size: 32px;
  letter-spacing: 2px;
}

.title {
  font-size: 48px;
  margin: 80px 0 20px;
}

.collection-link {
  display: flex;
  align-items: center;
  gap: 15px;
  font-style: italic;
}

.collection-link .line {
  height: 1px;
  width: 60px;
  background-color: #666;
}

.language-switch {
  font-size: 14px;
}

.language-switch .active {
  font-weight: bold;
}

.right-panel {
  background-color: #1c1c1c;
  color: white;
  position: relative;
  display: flex;
  flex-direction: column;
  justify-content: space-between;
}

.icons {
  display: flex;
  justify-content: flex-end;
  gap: 25px;
  font-size: 18px;
}

.ring-container {
  display: flex;
  justify-content: center;
  align-items: center;
}

.ring-container img {
  max-width: 100%;
  height: auto;
}

.ring-info {
  text-align: right;
  font-size: 14px;
  line-height: 1.5;
  margin-bottom: 30px;
}

.ring-info .price {
  color: #d4a649;
  font-weight: bold;
}

# %%
<!DOCTYPE html>
<html lang="ru">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0" />
  <title>Moon River</title>
  <link rel="stylesheet" href="styles.css" />
  <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.5.0/css/all.min.css" />
</head>
<body>
  <div class="container">
    <div class="left-panel">
      <h1 class="logo">Moon River</h1>
      <h2 class="title">HIGH JEWELRY</h2>
      <div class="collection-link">
        <div class="line"></div>
        <a href="#">Смотреть коллекцию</a>
      </div>
      <div class="language-switch">
        <span class="active">RU</span> <span>EN</span>
      </div>
    </div>

    <div class="right-panel">
      <div class="icons">
        <i class="fa-regular fa-heart"></i>
        <i class="fa-regular fa-user"></i>
        <i class="fa-solid fa-lock"></i>
        <i class="fa-solid fa-bars"></i>
      </div>
      <div class="ring-container">
        <img src="ring.png" alt="Кольцо" />
      </div>
      <div class="ring-info">
        <p><strong>КОЛЬЦО TRINITY, CARTIER</strong><br/>
        Белое золото, бриллианты<br/>
        <span class="price">498 000 Р</span></p>
      </div>
    </div>
  </div>
</body>
</html>
